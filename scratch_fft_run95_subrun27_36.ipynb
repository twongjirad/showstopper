# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from root_numpy import root2array, root2rec, tree2rec, array2root

# %%
run = 95
subrun1 = 27
subrun2 = 36
datafilename = 'data/pulser_run%03d_subrun%03d_%03d.root'%(run,subrun1,subrun2)
print datafilename
wf_arr = root2array( datafilename, 'wftree' )
wfdf = pd.DataFrame( wf_arr )
pl_arr = root2array( datafilename, 'ptree' )
pldf = pd.DataFrame( pl_arr )
# Out:
# data/pulser_run095_subrun027_036.root

# %%
print wfdf.columns
#print pldf.columns
tdc = 0.500 # microseconds
print tdc
# Out:
# Index([u'crate', u'slot', u'femch', u'max_amp', u'npulse', u'ped_mean', u'ped_rms', u'wf'], dtype='object')
# 0.5

# %%
pldf[pldf['amp']>90]
# Out:
#        crate  slot  femch     ped_mean   ped_rms         amp       charge  \
# 11224      9    16     19  2037.671265  6.101677   98.328735   720.847168
# 11231      9    16     19  2037.671265  6.101677  115.298706   964.496216
# 11239      9    16     19  2037.671265  6.101677  131.448853   917.426392
# 11243      9    16     19  2037.671265  6.101677  123.478638  1128.943481
# 11246      9    16     19  2037.671265  6.101677   90.208618   687.437256
#
#        tstart  width
# 11224    1429     10
# 11231    3428     11
# 11239    5429     11
# 11243    7428     13
# 11246    9429     10

# %%
#ex = df[ df['max_amp']>100 ]
#wfdf.query('crate==2 & slot==6 & femch==0')
#sig_arr = wfdf.query('crate==2 & slot==6 & femch==0')['wf']
# 7,4,0: 

queries = {}
colors = {}
badlist = [ (6,9,2),(6,12,16),(6,12,26),(6,12,28) ]
for badch in badlist:
    queries['pickup: (%d,%d,%d)'%badch] = 'crate==%d & slot==%d & femch==%d'%badch
    colors['pickup: (%d,%d,%d)'%badch] = 'blue'
queries['pulsed V1721 [9,16,19]'] = 'crate==9 & slot==16 & femch==19'
colors['pulsed V1721 [9,16,19]'] = 'red'
            
arrs = {}
ntdcs = 100
T = 100*tdc
for name,query in queries.items():
    arrs[name] = wfdf.query( query )['wf'].values[0]
    #print wfdf.query( query )['ped_mean'].values[0]
    arrs[name][:] -= wfdf.query( query )['ped_mean'].values[0]
print arrs.keys()
print 'Period: ',T,'microseconds'
# Out:
# ['pulsed V1721 [9,16,19]', 'pickup: (6,12,26)', 'pickup: (6,9,2)', 'pickup: (6,12,16)', 'pickup: (6,12,28)']
# Period:  50.0 microseconds

# %%
sig = 'pulsed V1721 [9,16,19]'

tstart = 1400
tend = 1500
for name in queries.keys():
    plt.figure()
    plt.plot(np.arange(0,tdc*len(arrs[name][tstart:tend]), tdc), arrs[name][tstart:tend], 'r',color=colors[name])
    plt.xlabel('microseconds')
    plt.grid()
    plt.title(name)
    plt.show()

# %%
class1 = [(6,9,2),(6,12,16),(6,12,26),(6,12,28)] # 
class2 = []
class3 = []
class4 = []

# %%
# backgrounds
plt.figure()
for name,arr in arrs.items():
    if name==sig:
        continue
    print name
    plt.plot(np.arange(0,tdc*len(arr[tstart:tend]), tdc), arr[tstart:tend], 'r',color=colors[name])
plt.xlabel('microseconds')
plt.ylabel('ADC')
plt.show()
# Out:
# pickup: (6,12,26)
# pickup: (6,9,2)
# pickup: (6,12,16)
# pickup: (6,12,28)

# %%
# FFT
fft_list = {}
nhalves = {}
for name,arr in arrs.items():
    xff = np.fft.fft( arr[tstart:tend] )
    xffc = np.conjugate( xff )
    xx = np.sqrt(np.real(xff*xffc))
    fft_list[name] = xx
    nhalves[name] = int(len(xx)/2)

# %%
f = 1/(2*tdc)/(ntdcs/2) # 2 MHz
f *= 1.0e3
print T,'microseconds'
print f,'kHz per bin'
plt.figure()
plt.plot(np.linspace(0,nhalves[sig]*f,nhalves[sig]), fft_list[sig][:int(nhalves[sig])], 'r',color=colors[sig])
plt.xlabel('freq. [kHz]')
plt.ylabel('|P(w)|')
plt.title('Power Spectrum: '+sig)
plt.grid()
plt.show()

# Set rgb-max
fftsig = fft_list[sig]
print '0-200 kHz:',np.max(fftsig[4:6]),np.argmax(fftsig[:10])
print '200-400 kHz:',np.max(fftsig[14:16]),np.argmax(fftsig[10:20])
print '400-600 kHz:',np.max(fftsig[24:26]),np.argmax(fftsig[20:30])
#rmax = np.max(fftsig[4:6])
#gmax = np.max(fftsig[14:16])
#bmax = np.max(fftsig[24:26])
rmax = np.max(fftsig[4:6])
gmax = np.max(fftsig[14:16])
bmax = np.max(fftsig[24:26])
# Out:
# 50.0 microseconds
# 20.0 kHz per bin
# 0-200 kHz: 1069.45738449 1
# 200-400 kHz: 105.352499709 0
# 400-600 kHz: 103.138883128 4

# %%
f = 1/(2*tdc)/(ntdcs/2) # 2 MHz
f *= 1.0e3
print f,'kHz'
plt.figure()
for name,fft in fft_list.items():
    if name==sig:
        continue
    nhalf = nhalves[name]
    plt.plot(np.linspace(0,nhalves[sig]*f,nhalves[sig]), fft[:nhalf], 'r',color=colors[name])
    rval = np.max(fft[4:7])/rmax
    gval = np.max(fft[14:17])/gmax
    bval = np.max(fft[24:27])/bmax
    print name,'rgb=',rval,gval,bval
plt.xlabel('freq. [kHz]')
plt.ylabel('|P(w)|')
plt.title('Power Spectrum')
plt.show()
# Out:
# 20.0 kHz
# pickup: (6,12,26) rgb= 0.156094249164 1.95571168231 1.54143826929
# pickup: (6,9,2) rgb= 0.261379956967 1.81306637533 1.92541895944
# pickup: (6,12,16)
#  rgb= 0.183720466422 2.29115659389 1.53476407759
# pickup: (6,12,28) rgb= 0.250392621057 0.815627950724 2.26294959886

# %%
f = 1/(2*tdc)/(ntdcs/2) # 2 MHz
f *= 1.0e3
print f,'kHz'

for name,fft in fft_list.items():
    if name==sig:
        continue
    nhalf = nhalves[name]
    plt.figure()
    plt.plot(np.linspace(0,nhalves[sig]*f,nhalves[sig]), fft[:nhalf], 'r',color=colors[name])
    rval = np.max(fft[4:7])/rmax
    gval = np.max(fft[14:17])/gmax
    bval = np.max(fft[24:27])/bmax
    print name,'rgb=',rval,gval,bval
    plt.xlabel('freq. [kHz]')
    plt.ylabel('|P(w)|')
    plt.title('Power Spectrum: '+name)
    plt.show()
# Out:
# 20.0 kHz
# pickup: (6,12,26)
#  rgb= 0.156094249164 1.95571168231 1.54143826929
# pickup: (6,9,2) rgb= 0.261379956967 1.81306637533 1.92541895944
# pickup: (6,12,16) rgb= 0.183720466422 2.29115659389 1.53476407759
# pickup: (6,12,28) rgb= 0.250392621057 0.815627950724 2.26294959886
