# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from root_numpy import root2array, root2rec, tree2rec, array2root

# %%
run = 95
subrun1 = 157
subrun2 = 166
datafilename = 'data/pulser_run%03d_subrun%03d_%03d.root'%(run,subrun1,subrun2)
print datafilename
wf_arr = root2array( datafilename, 'wftree' )
wfdf = pd.DataFrame( wf_arr )
pl_arr = root2array( datafilename, 'ptree' )
pldf = pd.DataFrame( pl_arr )
# Out:
# data/pulser_run095_subrun157_166.root

# %%
print wfdf.columns
#print pldf.columns
tdc = 0.500 # microseconds
print tdc
# Out:
# Index([u'crate', u'slot', u'femch', u'max_amp', u'npulse', u'ped_mean', u'ped_rms', u'wf'], dtype='object')
# 0.5

# %%
pldf[pldf['amp']>700]
# Out:
#        crate  slot  femch    ped_mean  ped_rms          amp       charge  \
# 10563      8    17     48  488.485016  4.71167  1055.844971  3040.150146
# 10564      8    17     48  488.485016  4.71167  1054.734985  3023.800049
# 10565      8    17     48  488.485016  4.71167  1062.195068  3047.700195
# 10566      8    17     48  488.485016  4.71167  1061.255005  3030.760254
# 10567      8    17     48  488.485016  4.71167  1052.405029  3032.209961
#
#        tstart  width
# 10563      38      6
# 10564    2038      6
# 10565    4038      6
# 10566    6038      6
# 10567    8038      6

# %%
queries = {}
colors = {}
badlist = [(6, 9, 0), (6, 9, 2), (6, 9, 6), (6, 9, 14), (6, 10, 24), (6, 11, 24), (6, 11, 30), (6, 12, 2), (6, 12, 18), (6, 12, 20), (6, 12, 26), (7, 4, 0), (7, 4, 2), (7, 4, 4), (7, 4, 6), (7, 5, 0), (7, 5, 24), (7, 5, 26), (7, 5, 28), (7, 5, 30), (8, 17, 47)]
print "N Badlist: ",len(badlist)
for badch in badlist:
    queries['pickup: (%d,%d,%d)'%badch] = 'crate==%d & slot==%d & femch==%d'%badch
    colors['pickup: (%d,%d,%d)'%badch] = 'blue'
queries['pulsed [8,17,48]'] = 'crate==8 & slot==17 & femch==48'
colors['pulsed [8,17,48]'] = 'red'
sig="pulsed [8,17,48]"
            
arrs = {}
ntdcs = 100
T = 100*tdc
for name,query in queries.items():
    arrs[name] = wfdf.query( query )['wf'].values[0]
    #print wfdf.query( query )['ped_mean'].values[0]
    arrs[name][:] -= wfdf.query( query )['ped_mean'].values[0]
print arrs.keys()
print 'Period: ',T,'microseconds'
# Out:
# N Badlist:  21
# ['pickup: (6,12,26)', 'pickup: (6,12,20)', 'pulsed [8,17,48]', 'pickup: (6,9,0)', 'pickup: (6,9,6)', 'pickup: (6,9,2)', 'pickup: (7,4,0)', 'pickup: (7,5,28)', 'pickup: (6,12,2)', 'pickup: (7,5,30)', 'pickup: (6,10,24)', 'pickup: (6,11,30)', 'pickup: (7,5,0)', 'pickup: (7,5,26)', 'pickup: (7,5,24)', 'pickup: (6,11,24)', 'pickup: (6,12,18)', 'pickup: (8,17,47)', 'pickup: (7,4,4)', 'pickup: (7,4,2)', 'pickup: (7,4,6)', 'pickup: (6,9,14)']
# Period:  50.0 microseconds

# %%
for name in queries.keys():
    plt.figure()
    plt.plot(np.arange(0,tdc*len(arrs[name][:100]), tdc), arrs[name][:100], 'r',color=colors[name])
    plt.xlabel('microseconds')
    plt.grid()
    plt.title(name)
    plt.show()

# %%
class1 = [(6,9,0),(6,9,2),(6,9,6),(6,9,14),(8,17,47),]
class2 = []
class3 = [(6,11,24),(6,11,30),(6,10,24),(6,12,2),(6,12,18),(6,12,20),(6,12,26),]
class4 = [(7,4,0),(7,4,2),(7,4,4),(7,4,6),(7,5,0),(7,5,24),(7,5,26),(7,5,28),(7,5,30)]
reject = []

# %%
plt.figure()
for name,arr in arrs.items():
    if name==sig:
        continue
    plt.plot(np.arange(0,tdc*len(arr[:100]), tdc), arr[:100], 'r',color=colors[name])
plt.xlabel('microseconds')
plt.ylabel('ADC')
plt.show()

plt.figure()
for channel in class1:
    name = 'pickup: (%d,%d,%d)'%channel
    if name==sig:
        continue
    plt.plot(np.arange(0,tdc*len(arrs[name][:100]), tdc), arrs[name][:100], 'r',color='red')
plt.xlabel('microseconds')
plt.ylabel('ADC')
plt.show()

plt.figure()
for channel in class2:
    name = 'pickup: (%d,%d,%d)'%channel
    if name==sig:
        continue
    plt.plot(np.arange(0,tdc*len(arrs[name][:100]), tdc), arrs[name][:100], 'r',color='red')
plt.xlabel('microseconds')
plt.ylabel('ADC')
plt.show()


plt.figure()
for channel in class3:
    name = 'pickup: (%d,%d,%d)'%channel
    if name==sig:
        continue
    plt.plot(np.arange(0,tdc*len(arrs[name][:100]), tdc), arrs[name][:100], 'r',color='red')
plt.xlabel('microseconds')
plt.ylabel('ADC')
plt.show()


plt.figure()
for channel in class4:
    name = 'pickup: (%d,%d,%d)'%channel
    if name==sig:
        continue
    plt.plot(np.arange(0,tdc*len(arrs[name][:100]), tdc), arrs[name][:100], 'r',color='red')
plt.xlabel('microseconds')
plt.ylabel('ADC')
plt.show()

plt.figure()
for channel in rejected:
    name = 'pickup: (%d,%d,%d)'%channel
    if name==sig:
        continue
    plt.plot(np.arange(0,tdc*len(arrs[name][:100]), tdc), arrs[name][:100], 'r',color='blue')
plt.xlabel('microseconds')
plt.ylabel('ADC')
plt.show()

# %%
# FFT
fft_list = {}
nhalves = {}
for name,arr in arrs.items():
    xff = np.fft.fft( arr[:100] )
    xffc = np.conjugate( xff )
    xx = np.sqrt(np.real(xff*xffc))
    fft_list[name] = xx
    nhalves[name] = int(len(xx)/2)

# %%
f = 1/(2*tdc)/(ntdcs/2) # 2 MHz
f *= 1.0e3
print T,'microseconds'
print f,'kHz per bin'
plt.figure()
plt.plot(np.linspace(0,nhalves[sig]*f,nhalves[sig]), fft_list[sig][:int(nhalves[sig])], 'r',color=colors[sig])
plt.xlabel('freq. [kHz]')
plt.ylabel('|P(w)|')
plt.title('Power Spectrum: '+sig)
plt.grid()
plt.show()

# Set rgb-max
fftsig = fft_list[sig]
print '0-200 kHz:',np.max(fftsig[4:6]),np.argmax(fftsig[:10])
print '200-400 kHz:',np.max(fftsig[14:16]),np.argmax(fftsig[10:20])
print '400-600 kHz:',np.max(fftsig[24:26]),np.argmax(fftsig[20:30])
rmax = np.max(fftsig[4:6])
gmax = np.max(fftsig[14:16])
bmax = np.max(fftsig[24:26])
# Out:
# 50.0 microseconds
# 20.0 kHz per bin
# 0-200 kHz: 4228.98293926 5
# 200-400 kHz: 2183.73437131 3
# 400-600 kHz: 686.200026094 0

# %%
testarr = arrs[sig]
dtestarr = np.diff( testarr )
print len(testarr)
print len(dtestarr)

# Diff
plt.figure()
plt.plot(np.arange(0,tdc*len(dtestarr[:100]), tdc), dtestarr[:100], 'r',color='red')
plt.show()

#FFT
testx = np.fft.fft(dtestarr[:100])
testxc = np.conjugate(testx)
testpw = np.sqrt( np.real(testx*testxc) )
plt.figure()
plt.plot(np.linspace(0,50*f,50), testpw[:50], 'r',color='red')
plt.show()
# Out:
# 9065
# 9064

# %%
f = 1/(2*tdc)/(ntdcs/2) # 2 MHz
f *= 1.0e3
print f,'kHz'
plt.figure()
for name,fft in fft_list.items():
    if name==sig:
        continue
    nhalf = nhalves[name]
    plt.plot(np.linspace(0,nhalves[sig]*f,nhalves[sig]), fft[:nhalf], 'r',color=colors[name])
    rval = np.max(fft[4:7])/rmax
    gval = np.max(fft[14:17])/gmax
    bval = np.max(fft[24:27])/bmax
    #print name,'rgb=',rval,gval,bval
plt.xlabel('freq. [kHz]')
plt.ylabel('|P(w)|')
plt.title('Power Spectrum')
plt.show()

# class1
f = 1/(2*tdc)/(ntdcs/2) # 2 MHz
f *= 1.0e3
print f,'kHz'
plt.figure()
for channel in class1:
    name = 'pickup: (%d,%d,%d)'%channel
    if name==sig:
        continue
    nhalf = nhalves[name]
    plt.plot(np.linspace(0,nhalves[sig]*f,nhalves[sig]), fft_list[name][:nhalf], 'r',color=colors[name])
    rval = np.max(fft_list[name][4:7])/rmax
    gval = np.max(fft_list[name][14:17])/gmax
    bval = np.max(fft_list[name][24:27])/bmax
    #print name,'rgb=',rval,gval,bval
plt.xlabel('freq. [kHz]')
plt.ylabel('|P(w)|')
plt.title('Power Spectrum')
plt.show()

# class2
f = 1/(2*tdc)/(ntdcs/2) # 2 MHz
f *= 1.0e3
print f,'kHz'
plt.figure()
for channel in class2:
    name = 'pickup: (%d,%d,%d)'%channel
    if name==sig:
        continue
    nhalf = nhalves[name]
    plt.plot(np.linspace(0,nhalves[sig]*f,nhalves[sig]), fft_list[name][:nhalf], 'r',color=colors[name])
    rval = np.max(fft_list[name][4:7])/rmax
    gval = np.max(fft_list[name][14:17])/gmax
    bval = np.max(fft_list[name][24:27])/bmax
    #print name,'rgb=',rval,gval,bval
plt.xlabel('freq. [kHz]')
plt.ylabel('|P(w)|')
plt.title('Power Spectrum')
plt.show()

# class3
f = 1/(2*tdc)/(ntdcs/2) # 2 MHz
f *= 1.0e3
print f,'kHz'
plt.figure()
for channel in class3:
    name = 'pickup: (%d,%d,%d)'%channel
    if name==sig:
        continue
    nhalf = nhalves[name]
    plt.plot(np.linspace(0,nhalves[sig]*f,nhalves[sig]), fft_list[name][:nhalf], 'r',color=colors[name])
    rval = np.max(fft_list[name][4:7])/rmax
    gval = np.max(fft_list[name][14:17])/gmax
    bval = np.max(fft_list[name][24:27])/bmax
    #print name,'rgb=',rval,gval,bval
plt.xlabel('freq. [kHz]')
plt.ylabel('|P(w)|')
plt.title('Power Spectrum')
plt.show()

# class4
f = 1/(2*tdc)/(ntdcs/2) # 2 MHz
f *= 1.0e3
print f,'kHz'
plt.figure()
for channel in class4:
    name = 'pickup: (%d,%d,%d)'%channel
    if name==sig:
        continue
    nhalf = nhalves[name]
    plt.plot(np.linspace(0,nhalves[sig]*f,nhalves[sig]), fft_list[name][:nhalf], 'r',color=colors[name])
    rval = np.max(fft_list[name][4:7])/rmax
    gval = np.max(fft_list[name][14:17])/gmax
    bval = np.max(fft_list[name][24:27])/bmax
    #print name,'rgb=',rval,gval,bval
plt.xlabel('freq. [kHz]')
plt.ylabel('|P(w)|')
plt.title('Power Spectrum')
plt.show()

# rejected
f = 1/(2*tdc)/(ntdcs/2) # 2 MHz
f *= 1.0e3
print f,'kHz'
plt.figure()
for channel in rejected:
    name = 'pickup: (%d,%d,%d)'%channel
    if name==sig:
        continue
    nhalf = nhalves[name]
    plt.plot(np.linspace(0,nhalves[sig]*f,nhalves[sig]), fft_list[name][:nhalf], 'r',color=colors[name])
    rval = np.max(fft_list[name][4:7])/rmax
    gval = np.max(fft_list[name][14:17])/gmax
    bval = np.max(fft_list[name][24:27])/bmax
    #print name,'rgb=',rval,gval,bval
plt.xlabel('freq. [kHz]')
plt.ylabel('|P(w)|')
plt.title('Power Spectrum')
plt.show()
# Out:
# 20.0 kHz
# 20.0 kHz
# 20.0 kHz
# 20.0 kHz
# 20.0 kHz
# 20.0 kHz

# %%
f = 1/(2*tdc)/(ntdcs/2) # 2 MHz
f *= 1.0e3
print f,'kHz'

for name,fft in fft_list.items():
    if name==sig:
        continue
    plt.figure()
    nhalf = nhalves[name]
    plt.plot(np.linspace(0,nhalves[sig]*f,nhalves[sig]), fft[:nhalf], 'r',color=colors[name])
    rval = np.max(fft[4:7])/rmax
    gval = np.max(fft[14:17])/gmax
    bval = np.max(fft[24:27])/bmax
    print name,'rgb=',rval,gval,bval
    plt.xlabel('freq. [kHz]')
    plt.ylabel('|P(w)|')
    plt.title('Power Spectrum: '+name)
    plt.show()
# Out:
# 20.0 kHz
# pickup: (6,12,26)
#  rgb= 0.0440487553465 0.0532559407882 0.225273854242
# pickup: (6,12,20) rgb= 0.0377124481173 0.065088757703 0.228290377278
# pickup: (6,9,0) rgb= 0.043711779189 0.0916305519016 0.323195839583
# pickup: (6,9,6) rgb= 0.0498240652319 0.100866982545 0.250222664002
# pickup: (8,17,47) rgb= 0.0964762034495 0.309501263939 0.574864691426
# pickup: (7,4,0) rgb= 0.135112339342 0.183553784703 0.52922883417
# pickup: (7,5,28) rgb= 0.162921866231 0.210765357612 0.347163325836
# pickup: (7,5,30) rgb= 0.157972709141 0.190426380463 0.382504940266
# pickup: (6,10,24) rgb= 0.0366623511226 0.118947316683 0.278741565012
# pickup: (6,11,30) rgb= 0.0578119810477 0.0492795012355 0.312327113453
# pickup: (7,5,0) rgb= 0.137020866517 0.217997576287 0.557927035553
# pickup: (7,5,26) rgb= 0.16908054203 0.172810532354 0.472770564586
# pickup: (7,5,24) rgb= 0.150303043913 0.206064368329 0.469210676627
# pickup: (6,11,24) rgb= 0.0637842931813 0.063503029844 0.397009977065
# pickup: (6,12,18) rgb= 0.0508133709773 0.0802486760397 0.275990662624
# pickup: (6,12,2) rgb= 0.0588342659893 0.0839008914819 0.28708027469
# pickup: (7,4,4) rgb= 0.135799735683 0.170152916132 0.51530238748
# pickup: (7,4,2) rgb= 0.134605202873 0.244423390596 0.486793891472
# pickup: (7,4,6) rgb= 0.142175017351 0.203145667077 0.57514872247
# pickup: (6,9,2) rgb= 0.0637895665925 0.0772065355134 0.263292343171
# pickup: (6,9,14) rgb= 0.04267295184 0.0919280755942 0.281158680923
