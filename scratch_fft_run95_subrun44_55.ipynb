# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from root_numpy import root2array, root2rec, tree2rec, array2root

# %%
run = 95
subrun1 = 44
subrun2 = 55
datafilename = 'data/pulser_run%03d_subrun%03d_%03d.root'%(run,subrun1,subrun2)
print datafilename
wf_arr = root2array( datafilename, 'wftree' )
wfdf = pd.DataFrame( wf_arr )
pl_arr = root2array( datafilename, 'ptree' )
pldf = pd.DataFrame( pl_arr )
# Out:
# data/pulser_run095_subrun044_055.root

# %%
print wfdf.columns
#print pldf.columns
tdc = 0.500 # microseconds
print tdc
# Out:
# Index([u'crate', u'slot', u'femch', u'max_amp', u'npulse', u'ped_mean', u'ped_rms', u'wf'], dtype='object')
# 0.5

# %%
pldf[pldf['amp']>700]
# Out:
#       crate  slot  femch     ped_mean   ped_rms         amp       charge  \
# 6092      6     9      0  2048.282471  8.295121  880.776855  2888.717529
# 6093      6     9      0  2048.282471  8.295121  870.098877  2895.192139
# 6094      6     9      0  2048.282471  8.295121  867.480225  2906.082031
# 6095      6     9      0  2048.282471  8.295121  866.819336  2876.031250
# 6096      6     9      0  2048.282471  8.295121  869.242920  2886.887207
#
#       tstart  tmax  width
# 6092      38    40      7
# 6093    2038  2040      7
# 6094    4038  4040      7
# 6095    6038  6040      7
# 6096    8038  8040      7

# %%
queries = {}
colors = {}
badlist = [ (6, 9, 2), (6, 9, 4), (6, 9, 6), (6, 9, 10), (6, 9, 12), (6, 9, 14), (6, 9, 24), (6, 10, 24), (6, 10, 26), (6, 11, 26), (6, 12, 0), (6, 12, 2), (6, 12, 4), (6, 12, 6), (6, 12, 10), (6, 12, 14), (6, 12, 16), (6, 12, 18), (6, 12, 20), (6, 12, 22), (6, 12, 24), (6, 12, 26), (6, 12, 28), (6, 12, 30), (7, 4, 0), (7, 4, 2), (7, 4, 4), (7, 4, 6), (7, 5, 0), (7, 5, 24), (7, 5, 26), (7, 5, 28), (7, 5, 30), (7, 10, 30)]
print "N Badlist: ",len(badlist)
for badch in badlist:
    queries['pickup: (%d,%d,%d)'%badch] = 'crate==%d & slot==%d & femch==%d'%badch
    colors['pickup: (%d,%d,%d)'%badch] = 'blue'
queries['pulsed [6,9,0]'] = 'crate==6 & slot==9 & femch==0'
colors['pulsed [6,9,0]'] = 'red'
sig="pulsed [6,9,0]"
# MB30, 

arrs = {}
ntdcs = 100
T = 100*tdc
for name,query in queries.items():
    arrs[name] = wfdf.query( query )['wf'].values[0]
    #print wfdf.query( query )['ped_mean'].values[0]
    arrs[name][:] -= wfdf.query( query )['ped_mean'].values[0]
print arrs.keys()
print 'Period: ',T,'microseconds'
# Out:
# N Badlist:  34
# ['pickup: (6,12,26)', 'pickup: (6,9,12)', 'pickup: (6,12,20)', 'pickup: (6,12,24)', 'pulsed [6,9,0]', 'pickup: (6,9,4)', 'pickup: (6,12,30)', 'pickup: (6,9,6)', 'pickup: (6,9,2)', 'pickup: (7,4,0)', 'pickup: (7,5,28)', 'pickup: (7,5,0)', 'pickup: (7,10,30)', 'pickup: (7,5,30)', 'pickup: (6,10,24)', 'pickup: (6,12,10)', 'pickup: (6,12,14)', 'pickup: (6,10,26)', 'pickup: (6,12,16)', 'pickup: (7,5,26)', 'pickup: (7,5,24)', 'pickup: (6,12,18)', 'pickup: (6,11,26)', 'pickup: (6,12,2)', 'pickup: (6,12,6)', 'pickup: (7,4,4)', 'pickup: (6,9,24)', 'pickup: (6,12,0)', 'pickup: (7,4,2)', 'pickup: (6,12,4)', 'pickup: (7,4,6)', 'pickup: (6,12,28)', 'pickup: (6,9,10)', 'pickup: (6,9,14)', 'pickup: (6,12,22)']
# Period:  50.0 microseconds

# %%
for name in queries.keys():
    plt.figure()
    plt.plot(np.arange(0,tdc*len(arrs[name][:100]), tdc), arrs[name][:100], 'r',color=colors[name])
    plt.xlabel('microseconds')
    plt.grid()
    plt.title(name)
    plt.show()

# %%
class1 = [(6,9,2),(6,9,4),(6,9,6),(6,9,12),(6,9,10),(6,9,14),(6,9,24),] # upward, diff (7, MB30, 2 ASICs,D4)
class2 = [(6,10,24),(6,10,26),(6,11,26),] # downward, diff (FT7,same MB29,2 asics,D1)
class3 = [(7,4,0),(7,4,2),(7,4,4),(7,4,6),(7,5,0),(7,5,24),(7,5,26),(7,5,28),(7,5,30),(7,10,30),] # upward, correlate (FT9, MB 36, 2 asics)
class4 = [(6,12,10),(6,12,14),(6,12,16),(6,12,18),(6,12,26),(6,12,20),(6,12,24),(6,12,30),
          (6,12,2),(6,12,6),(6,12,0),(6,12,4),(6,12,28),(6,12,22),]

rejected = []

# %%
plt.figure()
for name,arr in arrs.items():
    if name==sig:
        continue
    plt.plot(np.arange(0,tdc*len(arr[:100]), tdc), arr[:100], 'r',color=colors[name])
plt.xlabel('microseconds')
plt.ylabel('ADC')
plt.show()

plt.figure()
for channel in class1:
    name = 'pickup: (%d,%d,%d)'%channel
    if name==sig:
        continue
    plt.plot(np.arange(0,tdc*len(arrs[name][:100]), tdc), arrs[name][:100], 'r',color='red')
plt.xlabel('microseconds')
plt.ylabel('ADC')
plt.show()

plt.figure()
for channel in class2:
    name = 'pickup: (%d,%d,%d)'%channel
    if name==sig:
        continue
    plt.plot(np.arange(0,tdc*len(arrs[name][:100]), tdc), arrs[name][:100], 'r',color='red')
plt.xlabel('microseconds')
plt.ylabel('ADC')
plt.show()

plt.figure()
for channel in class3:
    name = 'pickup: (%d,%d,%d)'%channel
    if name==sig:
        continue
    plt.plot(np.arange(0,tdc*len(arrs[name][:100]), tdc), arrs[name][:100], 'r',color='red')
plt.xlabel('microseconds')
plt.ylabel('ADC')
plt.show()

plt.figure()
for channel in class4:
    name = 'pickup: (%d,%d,%d)'%channel
    if name==sig:
        continue
    plt.plot(np.arange(0,tdc*len(arrs[name][:100]), tdc), arrs[name][:100], 'r',color='red')
plt.xlabel('microseconds')
plt.ylabel('ADC')
plt.show()

plt.figure()
for channel in rejected:
    name = 'pickup: (%d,%d,%d)'%channel
    if name==sig:
        continue
    plt.plot(np.arange(0,tdc*len(arrs[name][:100]), tdc), arrs[name][:100], 'r',color='orange')
plt.xlabel('microseconds')
plt.ylabel('ADC')
plt.show()

# %%
# FFT
fft_list = {}
nhalves = {}
for name,arr in arrs.items():
    xff = np.fft.fft( arr[:100] )
    xffc = np.conjugate( xff )
    xx = np.sqrt(np.real(xff*xffc))
    fft_list[name] = xx
    nhalves[name] = int(len(xx)/2)

# %%
f = 1/(2*tdc)/(ntdcs/2) # 2 MHz
f *= 1.0e3
print T,'microseconds'
print f,'kHz per bin'
plt.figure()
plt.plot(np.linspace(0,nhalves[sig]*f,nhalves[sig]), fft_list[sig][:int(nhalves[sig])], 'r',color=colors[sig])
plt.xlabel('freq. [kHz]')
plt.ylabel('|P(w)|')
plt.title('Power Spectrum: '+sig)
plt.grid()
plt.show()

# Set rgb-max
fftsig = fft_list[sig]
print '0-200 kHz:',np.max(fftsig[4:6]),np.argmax(fftsig[:10])
print '200-400 kHz:',np.max(fftsig[14:16]),np.argmax(fftsig[10:20])
print '400-600 kHz:',np.max(fftsig[24:26]),np.argmax(fftsig[20:30])
rmax = np.max(fftsig[4:6])
gmax = np.max(fftsig[14:16])
bmax = np.max(fftsig[24:26])
# Out:
# 50.0 microseconds
# 20.0 kHz per bin
# 0-200 kHz: 4612.78315481 5
# 200-400 kHz: 2044.33538345 3
# 400-600 kHz: 788.734544768 7

# %%
testarr = arrs[sig]
dtestarr = np.diff( testarr )
print len(testarr)
print len(dtestarr)

# Diff
plt.figure()
plt.plot(np.arange(0,tdc*len(dtestarr[:100]), tdc), dtestarr[:100], 'r',color='red')
plt.show()

#FFT
testx = np.fft.fft(dtestarr[:100])
testxc = np.conjugate(testx)
testpw = np.sqrt( np.real(testx*testxc) )
plt.figure()
plt.plot(np.linspace(0,50*f,50), testpw[:50], 'r',color='red')
plt.show()
# Out:
# 9019
# 9018

# %%
f = 1/(2*tdc)/(ntdcs/2) # 2 MHz
f *= 1.0e3
print f,'kHz'
plt.figure()
for name,fft in fft_list.items():
    if name==sig:
        continue
    nhalf = nhalves[name]
    plt.plot(np.linspace(0,nhalves[sig]*f,nhalves[sig]), fft[:nhalf], 'r',color=colors[name])
    rval = np.max(fft[4:7])/rmax
    gval = np.max(fft[14:17])/gmax
    bval = np.max(fft[24:27])/bmax
    #print name,'rgb=',rval,gval,bval
plt.xlabel('freq. [kHz]')
plt.ylabel('|P(w)|')
plt.title('Power Spectrum')
plt.show()

# class1
f = 1/(2*tdc)/(ntdcs/2) # 2 MHz
f *= 1.0e3
print f,'kHz'
plt.figure()
for channel in class1:
    name = 'pickup: (%d,%d,%d)'%channel
    if name==sig:
        continue
    nhalf = nhalves[name]
    plt.plot(np.linspace(0,nhalves[sig]*f,nhalves[sig]), fft_list[name][:nhalf], 'r',color=colors[name])
    rval = np.max(fft_list[name][4:7])/rmax
    gval = np.max(fft_list[name][14:17])/gmax
    bval = np.max(fft_list[name][24:27])/bmax
    #print name,'rgb=',rval,gval,bval
plt.xlabel('freq. [kHz]')
plt.ylabel('|P(w)|')
plt.title('Power Spectrum')
plt.show()

# class2
f = 1/(2*tdc)/(ntdcs/2) # 2 MHz
f *= 1.0e3
print f,'kHz'
plt.figure()
for channel in class2:
    name = 'pickup: (%d,%d,%d)'%channel
    if name==sig:
        continue
    nhalf = nhalves[name]
    plt.plot(np.linspace(0,nhalves[sig]*f,nhalves[sig]), fft_list[name][:nhalf], 'r',color=colors[name])
    rval = np.max(fft_list[name][4:7])/rmax
    gval = np.max(fft_list[name][14:17])/gmax
    bval = np.max(fft_list[name][24:27])/bmax
    #print name,'rgb=',rval,gval,bval
plt.xlabel('freq. [kHz]')
plt.ylabel('|P(w)|')
plt.title('Power Spectrum')
plt.show()

# class3
f = 1/(2*tdc)/(ntdcs/2) # 2 MHz
f *= 1.0e3
print f,'kHz'
plt.figure()
for channel in class3:
    name = 'pickup: (%d,%d,%d)'%channel
    if name==sig:
        continue
    nhalf = nhalves[name]
    plt.plot(np.linspace(0,nhalves[sig]*f,nhalves[sig]), fft_list[name][:nhalf], 'r',color=colors[name])
    rval = np.max(fft_list[name][4:7])/rmax
    gval = np.max(fft_list[name][14:17])/gmax
    bval = np.max(fft_list[name][24:27])/bmax
    #print name,'rgb=',rval,gval,bval
plt.xlabel('freq. [kHz]')
plt.ylabel('|P(w)|')
plt.title('Power Spectrum')
plt.show()

# class4
f = 1/(2*tdc)/(ntdcs/2) # 2 MHz
f *= 1.0e3
print f,'kHz'
plt.figure()
for channel in class4:
    name = 'pickup: (%d,%d,%d)'%channel
    if name==sig:
        continue
    nhalf = nhalves[name]
    plt.plot(np.linspace(0,nhalves[sig]*f,nhalves[sig]), fft_list[name][:nhalf], 'r',color=colors[name])
    rval = np.max(fft_list[name][4:7])/rmax
    gval = np.max(fft_list[name][14:17])/gmax
    bval = np.max(fft_list[name][24:27])/bmax
    #print name,'rgb=',rval,gval,bval
plt.xlabel('freq. [kHz]')
plt.ylabel('|P(w)|')
plt.title('Power Spectrum')
plt.show()

# rejected
f = 1/(2*tdc)/(ntdcs/2) # 2 MHz
f *= 1.0e3
print f,'kHz'
plt.figure()
for channel in rejected:
    name = 'pickup: (%d,%d,%d)'%channel
    if name==sig:
        continue
    nhalf = nhalves[name]
    plt.plot(np.linspace(0,nhalves[sig]*f,nhalves[sig]), fft_list[name][:nhalf], 'r',color=colors[name])
    rval = np.max(fft_list[name][4:7])/rmax
    gval = np.max(fft_list[name][14:17])/gmax
    bval = np.max(fft_list[name][24:27])/bmax
    #print name,'rgb=',rval,gval,bval
plt.xlabel('freq. [kHz]')
plt.ylabel('|P(w)|')
plt.title('Power Spectrum')
plt.show()
# Out:
# 20.0 kHz
# 20.0 kHz
# 20.0 kHz
# 20.0 kHz
# 20.0 kHz
# 20.0 kHz

# %%
f = 1/(2*tdc)/(ntdcs/2) # 2 MHz
f *= 1.0e3
print f,'kHz'

for name,fft in fft_list.items():
    if name==sig:
        continue
    plt.figure()
    nhalf = nhalves[name]
    plt.plot(np.linspace(0,nhalves[sig]*f,nhalves[sig]), fft[:nhalf], 'r',color=colors[name])
    rval = np.max(fft[4:7])/rmax
    gval = np.max(fft[14:17])/gmax
    bval = np.max(fft[24:27])/bmax
    print name,'rgb=',rval,gval,bval
    plt.xlabel('freq. [kHz]')
    plt.ylabel('|P(w)|')
    plt.title('Power Spectrum: '+name)
    plt.show()
# Out:
# 20.0 kHz
# pickup: (6,12,26)
#  rgb= 0.0788982806874 0.0925938384652 0.368634554186
# pickup: (7,4,6) rgb= 0.121480194518 0.11758442477 0.3236659211
# pickup: (6,12,20) rgb= 0.0997906972755 0.151187983368 0.444861285227
# pickup: (6,12,24) rgb= 0.0706386087675 0.128769506087 0.307311293101
# pickup: (6,9,4) rgb= 0.0790662931478 0.254877923876 0.626934868957
# pickup: (6,12,30) rgb= 0.0810463588201 0.168740473627 0.226960067175
# pickup: (6,9,6) rgb= 0.0786805824399 0.239535965483 0.493599444377
# pickup: (6,9,2) rgb= 0.0710515278953 0.236242342059 0.571806947566
# pickup: (7,4,0) rgb= 0.112102777335 0.10745429147 0.313247743577
# pickup: (7,5,28) rgb= 0.113446246821 0.0721712577172 0.33268568896
# pickup: (7,5,0) rgb= 0.106297434683 0.134339360557 0.347938166865
# pickup: (7,10,30) rgb= 0.108378888319 0.190697682307 0.396260352191
# pickup: (7,5,30) rgb= 0.094401581957 0.0869032548993 0.316523701912
# pickup: (6,10,24) rgb= 0.0772427761203 0.185473270121 0.125078861482
# pickup: (6,12,10) rgb= 0.113508583591 0.234959737665 0.461320253221
# pickup: (6,12,14) rgb= 0.0956014937508 0.23020979169 0.483040786117
# pickup: (6,10,26) rgb= 0.0736620662071 0.120531162373 0.273925652499
# pickup: (6,12,16) rgb= 0.0908694057697 0.178483247752 0.493555265916
# pickup: (7,5,26) rgb= 0.106373742262 0.143284324471 0.338249505675
# pickup: (7,5,24) rgb= 0.117059270331 0.162258339162 0.381735153553
# pickup: (6,12,18) rgb= 0.093442650281 0.163194773443 0.403785793017
# pickup: (6,11,26) rgb= 0.0579479051619 0.119138162386 0.19107530684
# pickup: (6,12,2) rgb= 0.122992740709 0.210380243185 0.513881778461
# pickup: (6,12,6) rgb= 0.101718351605 0.1842791998 0.48451449717
# pickup: (7,4,4) rgb= 0.11316235212 0.0975571209279 0.298962594027
# pickup: (6,9,24) rgb= 0.0400442190118 0.184403779149 0.514798313061
# pickup: (6,12,0) rgb= 0.120033564062 0.237686939499 0.56409375283
# pickup: (7,4,2) rgb= 0.109162552219 0.155110788701 0.4097256978
# pickup: (6,12,4) rgb= 0.137683093029 0.191125489505 0.470006501659
# pickup: (6,9,12) rgb= 0.0766126822696 0.148897850089 0.441727075424
# pickup: (6,12,28) rgb= 0.0704017632466 0.0982293273882 0.346524497325
# pickup: (6,9,10) rgb= 0.0706506884841 0.243074881867 0.596639082224
