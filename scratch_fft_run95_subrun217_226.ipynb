# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from root_numpy import root2array, root2rec, tree2rec, array2root

# %%
run = 95
subrun1 = 217
subrun2 = 226
datafilename = 'data/pulser_run%03d_subrun%03d_%03d.root'%(run,subrun1,subrun2)
print datafilename
wf_arr = root2array( datafilename, 'wftree' )
wfdf = pd.DataFrame( wf_arr )
pl_arr = root2array( datafilename, 'ptree' )
pldf = pd.DataFrame( pl_arr )
# Out:
# data/pulser_run095_subrun217_226.root

# %%
print wfdf.columns
#print pldf.columns
tdc = 0.500 # microseconds
print tdc
# Out:
# Index([u'crate', u'slot', u'femch', u'max_amp', u'npulse', u'ped_mean', u'ped_rms', u'wf'], dtype='object')
# 0.5

# %%
pldf[pldf['amp']>60]
# Out:
#        crate  slot  femch     ped_mean    ped_rms         amp      charge  \
# 17050      9    16     19  2046.060181  13.456517   90.759888  571.818726
# 17051      9    16     19  2046.060181  13.456517  118.609741  693.738403
# 17052      9    16     19  2046.060181  13.456517   85.889771  310.259277
# 17053      9    16     19  2046.060181  13.456517  109.649780  782.378662
#
#        tstart  width
# 17050    1831      7
# 17051    3831      7
# 17052    5832      4
# 17053    7830      8

# %%
queries = {}
colors = {}
badlist = [(6,9,2),(6,12,16),(6,12,26),(6,12,28),(9, 14, 47), (9, 16, 2), (9, 16, 14)]
print "N Badlist: ",len(badlist)
for badch in badlist:
    queries['pickup: (%d,%d,%d)'%badch] = 'crate==%d & slot==%d & femch==%d'%badch
    colors['pickup: (%d,%d,%d)'%badch] = 'blue'
queries['pulsed [9,16,19]'] = 'crate==9 & slot==16 & femch==19'
colors['pulsed [9,16,19]'] = 'red'
sig="pulsed [9,16,19]"
            
arrs = {}
ntdcs = 100
T = 100*tdc
for name,query in queries.items():
    arrs[name] = wfdf.query( query )['wf'].values[0]
    #print wfdf.query( query )['ped_mean'].values[0]
    arrs[name][:] -= wfdf.query( query )['ped_mean'].values[0]
print arrs.keys()
print 'Period: ',T,'microseconds'
# Out:
# N Badlist:  7
# ['pickup: (6,12,26)', 'pickup: (6,12,16)', 'pickup: (9,16,2)', 'pickup: (6,12,28)', 'pulsed [9,16,19]', 'pickup: (9,16,14)', 'pickup: (9,14,47)', 'pickup: (6,9,2)']
# Period:  50.0 microseconds

# %%
plt.figure()
plt.plot(np.arange(0,tdc*len(arrs[sig]), tdc), arrs[sig], 'r',color=colors[sig])
plt.xlabel('microseconds')
plt.grid()
plt.title(sig)
plt.show()

tstart = 1800
tend = 1900
for name in queries.keys():
    plt.figure()
    plt.plot(np.arange(0,tdc*len(arrs[name][tstart:tend]), tdc), arrs[name][tstart:tend], 'r',color=colors[name])
    plt.xlabel('microseconds')
    plt.grid()
    plt.title(name)
    plt.show()

# %%
class1 = [(6,9,2),(6,12,16),(6,12,26),(6,12,28),(9,16,2),(9,16,14),]
class2 = []
class3 = []
class4 = []
rejected = [(9,14,47)]

# %%
plt.figure()
for name,arr in arrs.items():
    if name==sig:
        continue
    plt.plot(np.arange(0,tdc*len(arr[tstart:tend]), tdc), arr[tstart:tend], 'r',color=colors[name])
plt.xlabel('microseconds')
plt.ylabel('ADC')
plt.show()

plt.figure()
for channel in class1:
    name = 'pickup: (%d,%d,%d)'%channel
    if name==sig:
        continue
    plt.plot(np.arange(0,tdc*len(arrs[name][tstart:tend]), tdc), arrs[name][tstart:tend], 'r',color='red')
plt.xlabel('microseconds')
plt.ylabel('ADC')
plt.show()

plt.figure()
for channel in class2:
    name = 'pickup: (%d,%d,%d)'%channel
    if name==sig:
        continue
    plt.plot(np.arange(0,tdc*len(arrs[name][tstart:tend]), tdc), arrs[name][tstart:tend], 'r',color='red')
plt.xlabel('microseconds')
plt.ylabel('ADC')
plt.show()

plt.figure()
for channel in class3:
    name = 'pickup: (%d,%d,%d)'%channel
    if name==sig:
        continue
    plt.plot(np.arange(0,tdc*len(arrs[name][tstart:tend]), tdc), arrs[name][tstart:tend], 'r',color='red')
plt.xlabel('microseconds')
plt.ylabel('ADC')
plt.show()

plt.figure()
for channel in class4:
    name = 'pickup: (%d,%d,%d)'%channel
    if name==sig:
        continue
    plt.plot(np.arange(0,tdc*len(arrs[name][tstart:tend]), tdc), arrs[name][tstart:tend], 'r',color='red')
plt.xlabel('microseconds')
plt.ylabel('ADC')
plt.show()

plt.figure()
for channel in rejected:
    name = 'pickup: (%d,%d,%d)'%channel
    if name==sig:
        continue
    plt.plot(np.arange(0,tdc*len(arrs[name][tstart:tend]), tdc), arrs[name][tstart:tend], 'r',color='blue')
plt.xlabel('microseconds')
plt.ylabel('ADC')
plt.show()

# %%
# FFT
fft_list = {}
nhalves = {}
for name,arr in arrs.items():
    xff = np.fft.fft( arr[tstart:tend] )
    xffc = np.conjugate( xff )
    xx = np.sqrt(np.real(xff*xffc))
    fft_list[name] = xx
    nhalves[name] = int(len(xx)/2)

# %%
f = 1/(2*tdc)/(ntdcs/2) # 2 MHz
f *= 1.0e3
print T,'microseconds'
print f,'kHz per bin'
plt.figure()
plt.plot(np.linspace(0,nhalves[sig]*f,nhalves[sig]), fft_list[sig][:int(nhalves[sig])], 'r',color=colors[sig])
plt.xlabel('freq. [kHz]')
plt.ylabel('|P(w)|')
plt.title('Power Spectrum: '+sig)
plt.grid()
plt.show()

# Set rgb-max
fftsig = fft_list[sig]
print '0-200 kHz:',np.max(fftsig[4:6]),np.argmax(fftsig[:10])
print '200-400 kHz:',np.max(fftsig[14:16]),np.argmax(fftsig[10:20])
print '400-600 kHz:',np.max(fftsig[24:26]),np.argmax(fftsig[20:30])
#rmax = np.max(fftsig[4:6])
#gmax = np.max(fftsig[14:16])
#bmax = np.max(fftsig[24:26])
rmax = np.max(fftsig[4:6])
gmax = np.max(fftsig[14:16])
bmax = np.max(fftsig[24:26])
# Out:
# 50.0 microseconds
# 20.0 kHz per bin
# 0-200 kHz: 1110.16906817 0
# 200-400 kHz: 163.257703578 3
# 400-600 kHz: 93.3041860441 3

# %%
f = 1/(2*tdc)/(ntdcs/2) # 2 MHz
f *= 1.0e3
print f,'kHz'
plt.figure()
for name,fft in fft_list.items():
    if name==sig:
        continue
    nhalf = nhalves[name]
    plt.plot(np.linspace(0,nhalves[sig]*f,nhalves[sig]), fft[:nhalf], 'r',color=colors[name])
    rval = np.max(fft[4:7])/rmax
    gval = np.max(fft[14:17])/gmax
    bval = np.max(fft[24:27])/bmax
    print name,'rgb=',rval,gval,bval
plt.xlabel('freq. [kHz]')
plt.ylabel('|P(w)|')
plt.title('Power Spectrum')
plt.show()
# Out:
# 20.0 kHz
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-57716f0d6788> in <module>()
#       8     nhalf = nhalves[name]
#       9     plt.plot(np.linspace(0,nhalves[sig]*f,nhalves[sig]), fft[:nhalf], 'r',color=colors[name])
# ---> 10     rval = np.max(fft[4:7])/rmax
#      11     gval = np.max(fft[14:17])/gmax
#      12     bval = np.max(fft[24:27])/bmax
#
# NameError: name 'rmax' is not defined

# %%
f = 1/(2*tdc)/(ntdcs/2) # 2 MHz
f *= 1.0e3
print f,'kHz'

for name,fft in fft_list.items():
    if name==sig:
        continue
    nhalf = nhalves[name]
    plt.figure()
    plt.plot(np.linspace(0,nhalves[sig]*f,nhalves[sig]), fft[:nhalf], 'r',color=colors[name])
    rval = np.max(fft[4:7])/rmax
    gval = np.max(fft[14:17])/gmax
    bval = np.max(fft[24:27])/bmax
    print name,'rgb=',rval,gval,bval
    plt.xlabel('freq. [kHz]')
    plt.ylabel('|P(w)|')
    plt.title('Power Spectrum: '+name)
    plt.show()
# Out:
# 20.0 kHz
# pickup: (9,16,2) rgb= 0.156693473066 0.861076762962 1.69145695932
# pickup: (9,16,14) rgb= 0.0998127381452 0.883970446466 1.61929373218
# pickup: (9,14,47) rgb= 0.174843330585 0.727253980108 1.77593625523
