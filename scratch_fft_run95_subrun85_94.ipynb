# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from root_numpy import root2array, root2rec, tree2rec, array2root

# %%
run = 95
subrun1 = 85
subrun2 = 94
datafilename = 'data/pulser_run%03d_subrun%03d_%03d.root'%(run,subrun1,subrun2)
print datafilename
wf_arr = root2array( datafilename, 'wftree' )
wfdf = pd.DataFrame( wf_arr )
pl_arr = root2array( datafilename, 'ptree' )
pldf = pd.DataFrame( pl_arr )
# Out:
# data/pulser_run095_subrun085_094.root

# %%
print wfdf.columns
#print pldf.columns
tdc = 0.500 # microseconds
print tdc
# Out:
# Index([u'crate', u'slot', u'femch', u'max_amp', u'npulse', u'ped_mean', u'ped_rms', u'wf'], dtype='object')
# 0.5

# %%
pldf[pldf['amp']>700]
# Out:
#       crate  slot  femch    ped_mean   ped_rms         amp       charge  \
# 5928      7     4      0  2038.24353  8.578108  842.352173  3053.467773
# 5929      7     4      0  2038.24353  8.578108  795.330933  2922.062500
# 5930      7     4      0  2038.24353  8.578108  818.618286  2971.265137
# 5931      7     4      0  2038.24353  8.578108  814.756470  3008.104980
# 5932      7     4      0  2038.24353  8.578108  818.873413  2973.871094
#
#       tstart  width
# 5928      38      9
# 5929    2038      8
# 5930    4038      8
# 5931    6038      8
# 5932    8038      8

# %%
queries = {}
colors = {}
badlist = [(6, 9, 2), (6, 9, 4), (6, 12, 14), (6, 12, 20), (7, 4, 2), (7, 4, 6), (7, 5, 0), (7, 5, 30), (7, 11, 30), (9, 14, 47), (9, 16, 14)]
print "N Badlist: ",len(badlist)
for badch in badlist:
    queries['pickup: (%d,%d,%d)'%badch] = 'crate==%d & slot==%d & femch==%d'%badch
    colors['pickup: (%d,%d,%d)'%badch] = 'blue'
queries['pulsed [7,4,0]'] = 'crate==7 & slot==4 & femch==0'
colors['pulsed [7,4,0]'] = 'red'
sig="pulsed [7,4,0]"
            
arrs = {}
ntdcs = 100
T = 100*tdc
for name,query in queries.items():
    arrs[name] = wfdf.query( query )['wf'].values[0]
    #print wfdf.query( query )['ped_mean'].values[0]
    arrs[name][:] -= wfdf.query( query )['ped_mean'].values[0]
print arrs.keys()
print 'Period: ',T,'microseconds'
# Out:
# N Badlist:  11
# ['pickup: (6,12,14)', 'pulsed [7,4,0]', 'pickup: (7,4,6)', 'pickup: (7,11,30)', 'pickup: (7,5,0)', 'pickup: (6,12,20)', 'pickup: (7,4,2)', 'pickup: (6,9,4)', 'pickup: (7,5,30)', 'pickup: (9,16,14)', 'pickup: (9,14,47)', 'pickup: (6,9,2)']
# Period:  50.0 microseconds

# %%
for name in queries.keys():
    plt.figure()
    plt.plot(np.arange(0,tdc*len(arrs[name][:100]), tdc), arrs[name][:100], 'r',color=colors[name])
    plt.xlabel('microseconds')
    plt.grid()
    plt.title(name)
    plt.show()

# %%
class1 = [(6,9,4),(6,9,2),]
class2 = [(7,4,2),(7,4,6)]
class3 = [(9,14,47),(6,12,14),(6,12,20),]
class4 = [(7,5,0),(7,5,30),(7,11,30),] # anti-corr
rejected = [(9,16,14)]

# %%
plt.figure()
for name,arr in arrs.items():
    if name==sig:
        continue
    plt.plot(np.arange(0,tdc*len(arr[:100]), tdc), arr[:100], 'r',color=colors[name])
plt.xlabel('microseconds')
plt.ylabel('ADC')
plt.show()

plt.figure()
for channel in class1:
    name = 'pickup: (%d,%d,%d)'%channel
    if name==sig:
        continue
    plt.plot(np.arange(0,tdc*len(arrs[name][:100]), tdc), arrs[name][:100], 'r',color='red')
plt.xlabel('microseconds')
plt.ylabel('ADC')
plt.title('Class 1')
plt.show()

plt.figure()
for channel in class2:
    name = 'pickup: (%d,%d,%d)'%channel
    if name==sig:
        continue
    plt.plot(np.arange(0,tdc*len(arrs[name][:100]), tdc), arrs[name][:100], 'r',color='red')
plt.xlabel('microseconds')
plt.ylabel('ADC')
plt.title('Class 2')
plt.show()

plt.figure()
for channel in class3:
    name = 'pickup: (%d,%d,%d)'%channel
    if name==sig:
        continue
    plt.plot(np.arange(0,tdc*len(arrs[name][:100]), tdc), arrs[name][:100], 'r',color='red')
plt.xlabel('microseconds')
plt.ylabel('ADC')
plt.title('Class 3')
plt.show()

plt.figure()
for channel in class4:
    name = 'pickup: (%d,%d,%d)'%channel
    if name==sig:
        continue
    plt.plot(np.arange(0,tdc*len(arrs[name][:100]), tdc), arrs[name][:100], 'r',color='red')
plt.xlabel('microseconds')
plt.ylabel('ADC')
plt.title('Class 4')
plt.show()

plt.figure()
for channel in rejected:
    name = 'pickup: (%d,%d,%d)'%channel
    if name==sig:
        continue
    plt.plot(np.arange(0,tdc*len(arrs[name][:100]), tdc), arrs[name][:100], 'r',color='red')
plt.xlabel('microseconds')
plt.ylabel('ADC')
plt.title('rejected')
plt.show()

# %%
# FFT
fft_list = {}
nhalves = {}
for name,arr in arrs.items():
    xff = np.fft.fft( arr[:100] )
    xffc = np.conjugate( xff )
    xx = np.sqrt(np.real(xff*xffc))
    fft_list[name] = xx
    nhalves[name] = int(len(xx)/2)

# %%
f = 1/(2*tdc)/(ntdcs/2) # 2 MHz
f *= 1.0e3
print T,'microseconds'
print f,'kHz per bin'
plt.figure()
plt.plot(np.linspace(0,nhalves[sig]*f,nhalves[sig]), fft_list[sig][:int(nhalves[sig])], 'r',color=colors[sig])
plt.xlabel('freq. [kHz]')
plt.ylabel('|P(w)|')
plt.title('Power Spectrum: '+sig)
plt.grid()
plt.show()

# Set rgb-max
fftsig = fft_list[sig]
print '0-200 kHz:',np.max(fftsig[4:6]),np.argmax(fftsig[:10])
print '200-400 kHz:',np.max(fftsig[14:16]),np.argmax(fftsig[10:20])
print '400-600 kHz:',np.max(fftsig[24:26]),np.argmax(fftsig[20:30])
rmax = np.max(fftsig[4:6])
gmax = np.max(fftsig[14:16])
bmax = np.max(fftsig[24:26])
# Out:
# 50.0 microseconds
# 20.0 kHz per bin
# 0-200 kHz: 4746.34352266 4
# 200-400 kHz: 1908.00766365 5
# 400-600 kHz: 702.055559017 5

# %%
testarr = arrs[sig]
dtestarr = np.diff( testarr )
print len(testarr)
print len(dtestarr)

# Diff
plt.figure()
plt.plot(np.arange(0,tdc*len(dtestarr[:100]), tdc), dtestarr[:100], 'r',color='red')
plt.show()

#FFT
testx = np.fft.fft(dtestarr[:100])
testxc = np.conjugate(testx)
testpw = np.sqrt( np.real(testx*testxc) )
plt.figure()
plt.plot(np.linspace(0,50*f,50), testpw[:50], 'r',color='red')
plt.show()
# Out:
# 9464
# 9463

# %%
f = 1/(2*tdc)/(ntdcs/2) # 2 MHz
f *= 1.0e3
print f,'kHz'
plt.figure()
for name,fft in fft_list.items():
    if name==sig:
        continue
    nhalf = nhalves[name]
    plt.plot(np.linspace(0,nhalves[sig]*f,nhalves[sig]), fft[:nhalf], 'r',color=colors[name])
    rval = np.max(fft[4:7])/rmax
    gval = np.max(fft[14:17])/gmax
    bval = np.max(fft[24:27])/bmax
    print name,'rgb=',rval,gval,bval
plt.xlabel('freq. [kHz]')
plt.ylabel('|P(w)|')
plt.title('Power Spectrum')
plt.show()
# Out:
# 20.0 kHz
# pickup: (6,12,14)
#  rgb= 0.0341719063484 0.110340353007 0.235289044004
# pickup: (7,4,2) rgb= 0.103349694686 0.199661982501 0.266652107131
# pickup: (7,11,30) rgb= 0.0558011930214 0.172184775622 0.224206390972
# pickup: (7,5,0) rgb= 0.0534312192185 0.233657482224 0.278336244607
# pickup: (6,12,20) rgb= 0.052860730299 0.106007363303 0.318478561471
# pickup: (7,4,6) rgb= 0.115149177561 0.271706073554 0.178946894873
# pickup: (6,9,4) rgb= 0.0376088485595 0.11200408843 0.295232545215
# pickup: (7,5,30) rgb= 0.0840588758087 0.118380727336 0.270391478733
# pickup: (9,16,14) rgb= 0.0194411722522 0.0917567703882 0.240104317937
# pickup: (9,14,47) rgb= 0.0571200677334 0.180172486552 0.240067002688
# pickup: (6,9,2) rgb= 0.0245973302058 0.115652014951 0.292108237395

# %%
f = 1/(2*tdc)/(ntdcs/2) # 2 MHz
f *= 1.0e3
print f,'kHz'

for name,fft in fft_list.items():
    if name==sig:
        continue
    plt.figure()
    nhalf = nhalves[name]
    plt.plot(np.linspace(0,nhalves[sig]*f,nhalves[sig]), fft[:nhalf], 'r',color=colors[name])
    rval = np.max(fft[4:7])/rmax
    gval = np.max(fft[14:17])/gmax
    bval = np.max(fft[24:27])/bmax
    print name,'rgb=',rval,gval,bval
    plt.xlabel('freq. [kHz]')
    plt.ylabel('|P(w)|')
    plt.title('Power Spectrum: '+name)
    plt.show()
# Out:
# 20.0 kHz
# pickup: (6,12,14)
#  rgb= 0.0341719063484 0.110340353007 0.235289044004
# pickup: (7,4,2) rgb= 0.103349694686 0.199661982501 0.266652107131
# pickup: (7,11,30) rgb= 0.0558011930214 0.172184775622 0.224206390972
# pickup: (7,5,0) rgb= 0.0534312192185 0.233657482224 0.278336244607
# pickup: (6,12,20) rgb= 0.052860730299 0.106007363303 0.318478561471
# pickup: (7,4,6) rgb= 0.115149177561 0.271706073554 0.178946894873
# pickup: (6,9,4) rgb= 0.0376088485595 0.11200408843 0.295232545215
# pickup: (7,5,30) rgb= 0.0840588758087 0.118380727336 0.270391478733
# pickup: (9,16,14) rgb= 0.0194411722522 0.0917567703882 0.240104317937
# pickup: (9,14,47) rgb= 0.0571200677334 0.180172486552 0.240067002688
# pickup: (6,9,2) rgb= 0.0245973302058 0.115652014951 0.292108237395
