# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from root_numpy import root2array, root2rec, tree2rec, array2root

# %%
run = 95
subrun1 = 174
subrun2 = 183
datafilename = 'data/pulser_run%03d_subrun%03d_%03d.root'%(run,subrun1,subrun2)
print datafilename
wf_arr = root2array( datafilename, 'wftree' )
wfdf = pd.DataFrame( wf_arr )
pl_arr = root2array( datafilename, 'ptree' )
pldf = pd.DataFrame( pl_arr )
# Out:
# data/pulser_run095_subrun174_183.root

# %%
print wfdf.columns
#print pldf.columns
tdc = 0.500 # microseconds
print tdc
# Out:
# Index([u'crate', u'slot', u'femch', u'max_amp', u'npulse', u'ped_mean', u'ped_rms', u'wf'], dtype='object')
# 0.5

# %%
pldf[pldf['amp']>700]
# Out:
#        crate  slot  femch    ped_mean  ped_rms          amp       charge  \
# 24808      8    17     47  494.677002  4.49104  1090.052979  3198.937988
# 24809      8    17     47  494.677002  4.49104  1081.762939  3181.497803
# 24810      8    17     47  494.677002  4.49104  1084.652954  3198.048096
# 24811      8    17     47  494.677002  4.49104  1078.133057  3169.998047
# 24812      8    17     47  494.677002  4.49104  1084.762939  3194.987793
#
#        tstart  width
# 24808      38      6
# 24809    2038      6
# 24810    4038      6
# 24811    6038      6
# 24812    8038      6

# %%
queries = {}
colors = {}
badlist = [(6, 9, 0), (6, 9, 4), (6, 9, 14), (6, 9, 24), (6, 11, 30), (6, 12, 18), (6, 12, 20), (7, 4, 0), (7, 4, 2), (7, 4, 4), (7, 4, 6), (7, 5, 0), (7, 5, 24), (7, 5, 26), (7, 5, 28), (7, 5, 30), (8, 17, 48), (9, 16, 22)]
print "N Badlist: ",len(badlist)
for badch in badlist:
    queries['pickup: (%d,%d,%d)'%badch] = 'crate==%d & slot==%d & femch==%d'%badch
    colors['pickup: (%d,%d,%d)'%badch] = 'blue'
queries['pulsed [8,17,47]'] = 'crate==8 & slot==17 & femch==47'
colors['pulsed [8,17,47]'] = 'red'
sig="pulsed [8,17,47]"
            
arrs = {}
ntdcs = 100
T = 100*tdc
for name,query in queries.items():
    arrs[name] = wfdf.query( query )['wf'].values[0]
    #print wfdf.query( query )['ped_mean'].values[0]
    arrs[name][:] -= wfdf.query( query )['ped_mean'].values[0]
print arrs.keys()
print 'Period: ',T,'microseconds'
# Out:
# N Badlist:  18
# ['pickup: (7,4,4)', 'pickup: (6,9,24)', 'pickup: (7,5,28)', 'pickup: (6,11,30)', 'pickup: (7,5,0)', 'pickup: (6,12,20)', 'pickup: (7,5,26)', 'pickup: (7,4,6)', 'pulsed [8,17,47]', 'pickup: (6,9,4)', 'pickup: (7,5,24)', 'pickup: (6,9,0)', 'pickup: (7,5,30)', 'pickup: (6,12,18)', 'pickup: (7,4,0)', 'pickup: (6,9,14)', 'pickup: (8,17,48)', 'pickup: (9,16,22)', 'pickup: (7,4,2)']
# Period:  50.0 microseconds

# %%
for name in queries.keys():
    plt.figure()
    plt.plot(np.arange(0,tdc*len(arrs[name][:100]), tdc), arrs[name][:100], 'r',color=colors[name])
    plt.xlabel('microseconds')
    plt.grid()
    plt.title(name)
    plt.show()

# %%
class1 = [(8,17,48)]
class2 = []
class3 = [(6,9,0),(6,9,4),(6,9,14),(6,9,24),(6,11,30),(6,12,18),(6,12,20)]
class4 = [(7,4,0),(7,4,2),(7,4,4),(7,4,6),(7,5,0),(7,5,24),(7,5,26),(7,5,30),(7,5,28)]
rejected = [(9,16,22)]

# %%
plt.figure()
for name,arr in arrs.items():
    if name==sig:
        continue
    plt.plot(np.arange(0,tdc*len(arr[:100]), tdc), arr[:100], 'r',color=colors[name])
plt.xlabel('microseconds')
plt.ylabel('ADC')
plt.show()

plt.figure()
for channel in class1:
    name = 'pickup: (%d,%d,%d)'%channel
    if name==sig:
        continue
    plt.plot(np.arange(0,tdc*len(arrs[name][:100]), tdc), arrs[name][:100], 'r',color='red')
plt.xlabel('microseconds')
plt.ylabel('ADC')
plt.show()

plt.figure()
for channel in class2:
    name = 'pickup: (%d,%d,%d)'%channel
    if name==sig:
        continue
    plt.plot(np.arange(0,tdc*len(arrs[name][:100]), tdc), arrs[name][:100], 'r',color='red')
plt.xlabel('microseconds')
plt.ylabel('ADC')
plt.show()

plt.figure()
for channel in class3:
    name = 'pickup: (%d,%d,%d)'%channel
    if name==sig:
        continue
    plt.plot(np.arange(0,tdc*len(arrs[name][:100]), tdc), arrs[name][:100], 'r',color='red')
plt.xlabel('microseconds')
plt.ylabel('ADC')
plt.show()

plt.figure()
for channel in class4:
    name = 'pickup: (%d,%d,%d)'%channel
    if name==sig:
        continue
    plt.plot(np.arange(0,tdc*len(arrs[name][:100]), tdc), arrs[name][:100], 'r',color='red')
plt.xlabel('microseconds')
plt.ylabel('ADC')
plt.show()

plt.figure()
for channel in rejected:
    name = 'pickup: (%d,%d,%d)'%channel
    if name==sig:
        continue
    plt.plot(np.arange(0,tdc*len(arrs[name][:100]), tdc), arrs[name][:100], 'r',color='blue')
plt.xlabel('microseconds')
plt.ylabel('ADC')
plt.show()

# %%
# FFT
fft_list = {}
nhalves = {}
for name,arr in arrs.items():
    xff = np.fft.fft( arr[:100] )
    xffc = np.conjugate( xff )
    xx = np.sqrt(np.real(xff*xffc))
    fft_list[name] = xx
    nhalves[name] = int(len(xx)/2)

# %%
f = 1/(2*tdc)/(ntdcs/2) # 2 MHz
f *= 1.0e3
print T,'microseconds'
print f,'kHz per bin'
plt.figure()
plt.plot(np.linspace(0,nhalves[sig]*f,nhalves[sig]), fft_list[sig][:int(nhalves[sig])], 'r',color=colors[sig])
plt.xlabel('freq. [kHz]')
plt.ylabel('|P(w)|')
plt.title('Power Spectrum: '+sig)
plt.grid()
plt.show()

# Set rgb-max
fftsig = fft_list[sig]
print '0-200 kHz:',np.max(fftsig[4:6]),np.argmax(fftsig[:10])
print '200-400 kHz:',np.max(fftsig[14:16]),np.argmax(fftsig[10:20])
print '400-600 kHz:',np.max(fftsig[24:26]),np.argmax(fftsig[20:30])
rmax = np.max(fftsig[4:6])
gmax = np.max(fftsig[14:16])
bmax = np.max(fftsig[24:26])
# Out:
# 50.0 microseconds
# 20.0 kHz per bin
# 0-200 kHz: 4358.03249973 4
# 200-400 kHz: 2225.78923029 3
# 400-600 kHz: 748.27155006 0

# %%
testarr = arrs[sig]
dtestarr = np.diff( testarr )
print len(testarr)
print len(dtestarr)

# Diff
plt.figure()
plt.plot(np.arange(0,tdc*len(dtestarr[:100]), tdc), dtestarr[:100], 'r',color='red')
plt.show()

#FFT
testx = np.fft.fft(dtestarr[:100])
testxc = np.conjugate(testx)
testpw = np.sqrt( np.real(testx*testxc) )
plt.figure()
plt.plot(np.linspace(0,50*f,50), testpw[:50], 'r',color='red')
plt.show()
# Out:
# 8362
# 8361

# %%
f = 1/(2*tdc)/(ntdcs/2) # 2 MHz
f *= 1.0e3
print f,'kHz'
plt.figure()
for name,fft in fft_list.items():
    if name==sig:
        continue
    nhalf = nhalves[name]
    plt.plot(np.linspace(0,nhalves[sig]*f,nhalves[sig]), fft[:nhalf], 'r',color=colors[name])
    rval = np.max(fft[4:7])/rmax
    gval = np.max(fft[14:17])/gmax
    bval = np.max(fft[24:27])/bmax
    #print name,'rgb=',rval,gval,bval
plt.xlabel('freq. [kHz]')
plt.ylabel('|P(w)|')
plt.title('Power Spectrum')
plt.show()

# class1
f = 1/(2*tdc)/(ntdcs/2) # 2 MHz
f *= 1.0e3
print f,'kHz'
plt.figure()
for channel in class1:
    name = 'pickup: (%d,%d,%d)'%channel
    if name==sig:
        continue
    nhalf = nhalves[name]
    plt.plot(np.linspace(0,nhalves[sig]*f,nhalves[sig]), fft_list[name][:nhalf], 'r',color=colors[name])
    rval = np.max(fft_list[name][4:7])/rmax
    gval = np.max(fft_list[name][14:17])/gmax
    bval = np.max(fft_list[name][24:27])/bmax
    #print name,'rgb=',rval,gval,bval
plt.xlabel('freq. [kHz]')
plt.ylabel('|P(w)|')
plt.title('Power Spectrum')
plt.show()

# class2
f = 1/(2*tdc)/(ntdcs/2) # 2 MHz
f *= 1.0e3
print f,'kHz'
plt.figure()
for channel in class2:
    name = 'pickup: (%d,%d,%d)'%channel
    if name==sig:
        continue
    nhalf = nhalves[name]
    plt.plot(np.linspace(0,nhalves[sig]*f,nhalves[sig]), fft_list[name][:nhalf], 'r',color=colors[name])
    rval = np.max(fft_list[name][4:7])/rmax
    gval = np.max(fft_list[name][14:17])/gmax
    bval = np.max(fft_list[name][24:27])/bmax
    #print name,'rgb=',rval,gval,bval
plt.xlabel('freq. [kHz]')
plt.ylabel('|P(w)|')
plt.title('Power Spectrum')
plt.show()

# class3
f = 1/(2*tdc)/(ntdcs/2) # 2 MHz
f *= 1.0e3
print f,'kHz'
plt.figure()
for channel in class3:
    name = 'pickup: (%d,%d,%d)'%channel
    if name==sig:
        continue
    nhalf = nhalves[name]
    plt.plot(np.linspace(0,nhalves[sig]*f,nhalves[sig]), fft_list[name][:nhalf], 'r',color=colors[name])
    rval = np.max(fft_list[name][4:7])/rmax
    gval = np.max(fft_list[name][14:17])/gmax
    bval = np.max(fft_list[name][24:27])/bmax
    #print name,'rgb=',rval,gval,bval
plt.xlabel('freq. [kHz]')
plt.ylabel('|P(w)|')
plt.title('Power Spectrum')

# class4
f = 1/(2*tdc)/(ntdcs/2) # 2 MHz
f *= 1.0e3
print f,'kHz'
plt.figure()
for channel in class4:
    name = 'pickup: (%d,%d,%d)'%channel
    if name==sig:
        continue
    nhalf = nhalves[name]
    plt.plot(np.linspace(0,nhalves[sig]*f,nhalves[sig]), fft_list[name][:nhalf], 'r',color=colors[name])
    rval = np.max(fft_list[name][4:7])/rmax
    gval = np.max(fft_list[name][14:17])/gmax
    bval = np.max(fft_list[name][24:27])/bmax
    #print name,'rgb=',rval,gval,bval
plt.xlabel('freq. [kHz]')
plt.ylabel('|P(w)|')
plt.title('Power Spectrum')
plt.show()

# rejected
f = 1/(2*tdc)/(ntdcs/2) # 2 MHz
f *= 1.0e3
print f,'kHz'
plt.figure()
for channel in rejected:
    name = 'pickup: (%d,%d,%d)'%channel
    if name==sig:
        continue
    nhalf = nhalves[name]
    plt.plot(np.linspace(0,nhalves[sig]*f,nhalves[sig]), fft_list[name][:nhalf], 'r',color=colors[name])
    rval = np.max(fft_list[name][4:7])/rmax
    gval = np.max(fft_list[name][14:17])/gmax
    bval = np.max(fft_list[name][24:27])/bmax
    #print name,'rgb=',rval,gval,bval
plt.xlabel('freq. [kHz]')
plt.ylabel('|P(w)|')
plt.title('Power Spectrum')
plt.show()
plt.show()
# Out:
# 20.0 kHz
# 20.0 kHz
# 20.0 kHz
# 20.0 kHz
# 20.0
#  kHz
# 20.0 kHz

# %%
f = 1/(2*tdc)/(ntdcs/2) # 2 MHz
f *= 1.0e3
print f,'kHz'

for name,fft in fft_list.items():
    if name==sig:
        continue
    plt.figure()
    nhalf = nhalves[name]
    plt.plot(np.linspace(0,nhalves[sig]*f,nhalves[sig]), fft[:nhalf], 'r',color=colors[name])
    rval = np.max(fft[4:7])/rmax
    gval = np.max(fft[14:17])/gmax
    bval = np.max(fft[24:27])/bmax
    print name,'rgb=',rval,gval,bval
    plt.xlabel('freq. [kHz]')
    plt.ylabel('|P(w)|')
    plt.title('Power Spectrum: '+name)
    plt.show()
# Out:
# 20.0 kHz
# pickup: (7,4,4) rgb= 0.114914560563 0.239329226476 0.413667823368
# pickup: (6,9,24) rgb= 0.0577879682456 0.154376291253 0.25531918074
# pickup: (7,5,28) rgb= 0.117680147226 0.183299053616 0.418877159141
# pickup: (6,11,30) rgb= 0.0487594444859 0.0925765741536 0.274893910583
# pickup: (7,5,0) rgb= 0.107178055113 0.207280824766 0.347087798108
# pickup: (6,12,20) rgb= 0.0133937012167 0.0849831104802 0.330836804827
# pickup: (7,5,26) rgb= 0.103956237208 0.25835849809 0.405430469889
# pickup: (7,4,6) rgb= 0.0891598569048 0.237751064817 0.436502530339
# pickup: (6,9,4) rgb= 0.0408948769069 0.116414454524 0.317347576962
# pickup: (7,5,24) rgb= 0.105692835417 0.190518561072 0.371521484007
# pickup: (6,9,0) rgb= 0.0474701594999 0.0746863415239 0.224722084112
# pickup: (7,5,30) rgb= 0.105435706114 0.229541332666 0.340549412814
# pickup: (6,12,18) rgb= 0.0288508313375 0.0486231978499 0.224835710421
# pickup: (7,4,2) rgb= 0.114660940426 0.234234513792 0.458344591552
# pickup: (6,9,14) rgb= 0.0446439655769 0.174048620998 0.192375377267
# pickup: (8,17,48) rgb= 0.0758013748001 0.308449450402 0.53670079254
# pickup: (9,16,22) rgb= 0.0293140739944 0.0647564209124 0.250454650902
# pickup: (7,4,0) rgb= 0.102991407341 0.189906035131 0.435601238624
