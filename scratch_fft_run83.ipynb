# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from root_numpy import root2array, root2rec, tree2rec, array2root

# %%
run = 83
subrun1 = 0
subrun2 = 0
datafilename = 'data/pulser_run%03d_subrun%03d_%03d.root'%(run,subrun1,subrun2)
print datafilename
wf_arr = root2array( datafilename, 'wftree' )
wfdf = pd.DataFrame( wf_arr )
pl_arr = root2array( datafilename, 'ptree' )
pldf = pd.DataFrame( pl_arr )
# Out:
# data/pulser_run083_subrun000_000.root

# %%
print wfdf.columns
#print pldf.columns
tdc = 0.500 # microseconds
print tdc
# Out:
# Index([u'crate', u'slot', u'femch', u'max_amp', u'npulse', u'ped_mean', u'ped_rms', u'wf'], dtype='object')
# 0.5

# %%
pldf[pldf['amp']>700]
# Out:
#       crate  slot  femch     ped_mean   ped_rms          amp       charge  \
# 7444      2     6      0  2033.389038  0.225925  1086.774536  3060.040039
# 7446      2     6      0  2033.389038  0.225925  1086.201782  3057.786133
# 7448      2     6      0  2033.389038  0.225925  1086.319946  3058.330811
# 7450      2     6      0  2033.389038  0.225925  1085.247437  3057.258545
# 7453      2     6      0  2033.389038  0.225925  1084.401978  3057.186035
#
#       tstart  width
# 7444      18      7
# 7446    2018      7
# 7448    4018      7
# 7450    6018      7
# 7453    8018      7

# %%
queries = {}
colors = {}
badlist = [ (6,9,4),(6,11,14),(6,12,8),(7,5,4),(7,10,0)]
for badch in badlist:
    queries['pickup: (%d,%d,%d)'%badch] = 'crate==%d & slot==%d & femch==%d'%badch
    colors['pickup: (%d,%d,%d)'%badch] = 'blue'
queries['pulsed [2,6,0]'] = 'crate==2 & slot==6 & femch==0'
colors['pulsed [2,6,0]'] = 'red'
            
arrs = {}
ntdcs = 100
T = 100*tdc
for name,query in queries.items():
    arrs[name] = wfdf.query( query )['wf'].values[0]
    #print wfdf.query( query )['ped_mean'].values[0]
    arrs[name][:] -= wfdf.query( query )['ped_mean'].values[0]
print arrs.keys()
print 'Period: ',T,'microseconds'
# Out:
# ['pickup: (7,10,0)', 'pickup: (7,5,4)', 'pickup: (6,9,4)', 'pickup: (6,12,8)', 'pulsed [2,6,0]', 'pickup: (6,11,14)']
# Period:  50.0 microseconds

# %%
wired = 864 # from Jonanathan, Plane U

# %%
for name in queries.keys():
    plt.figure()
    plt.plot(np.arange(0,tdc*len(arrs[name][:100]), tdc), arrs[name][:100], 'r',color=colors[name])
    plt.xlabel('microseconds')
    plt.grid()
    plt.title(name)
    plt.show()

# %%
sig="pulsed [2,6,0]"
plt.figure()
for name,arr in arrs.items():
    if name==sig:
        continue
    plt.plot(np.arange(0,tdc*len(arr[:100]), tdc), arr[:100], 'r',color=colors[name])
plt.xlabel('microseconds')
plt.ylabel('ADC')
plt.show()

# %%
# FFT
fft_list = {}
nhalves = {}
for name,arr in arrs.items():
    xff = np.fft.fft( arr[:100] )
    xffc = np.conjugate( xff )
    xx = np.sqrt(np.real(xff*xffc))
    fft_list[name] = xx
    nhalves[name] = int(len(xx)/2)

# %%
f = 1/(2*tdc)/(ntdcs/2) # 2 MHz
f *= 1.0e3
print T,'microseconds'
print f,'kHz per bin'
plt.figure()
plt.plot(np.linspace(0,nhalves[sig]*f,nhalves[sig]), fft_list[sig][:int(nhalves[sig])], 'r',color=colors[sig])
plt.xlabel('freq. [kHz]')
plt.ylabel('|P(w)|')
plt.title('Power Spectrum: '+sig)
plt.grid()
plt.show()

# Set rgb-max
fftsig = fft_list[sig]
print '0-200 kHz:',np.max(fftsig[4:6]),np.argmax(fftsig[:10])
print '200-400 kHz:',np.max(fftsig[14:16]),np.argmax(fftsig[10:20])
print '400-600 kHz:',np.max(fftsig[24:26]),np.argmax(fftsig[20:30])
rmax = np.max(fftsig[4:6])
gmax = np.max(fftsig[14:16])
bmax = np.max(fftsig[24:26])
# Out:
# 50.0 microseconds
# 20.0 kHz per bin
# 0-200 kHz: 5024.45732133 5
# 200-400 kHz: 2797.53569615 4
# 400-600 kHz: 1008.28597573 6

# %%
f = 1/(2*tdc)/(ntdcs/2) # 2 MHz
f *= 1.0e3
print f,'kHz'
plt.figure()
for name,fft in fft_list.items():
    if name==sig:
        continue
    nhalf = nhalves[name]
    plt.plot(np.linspace(0,nhalves[sig]*f,nhalves[sig]), fft[:nhalf], 'r',color=colors[name])
    rval = np.max(fft[4:7])/rmax
    gval = np.max(fft[14:17])/gmax
    bval = np.max(fft[24:27])/bmax
    print name,'rgb=',rval,gval,bval
plt.xlabel('freq. [kHz]')
plt.ylabel('|P(w)|')
plt.title('Power Spectrum')
plt.show()
# Out:
# 20.0 kHz
# pickup: (7,10,0)
#  rgb= 0.0215238613606 0.0358794868981 0.1049272274
# pickup: (7,5,4) rgb= 0.0176022827032 0.0708870562484 0.147503911329
# pickup: (6,9,4) rgb= 0.035072950072 0.0657319250439 0.202375140648
# pickup: (6,12,8) rgb= 0.0157653323812 0.0598989810761 0.114497531027
# pickup: (6,11,14) rgb= 0.0321308441575 0.0919027207461 0.117359472206

# %%
f = 1/(2*tdc)/(ntdcs/2) # 2 MHz
f *= 1.0e3
print f,'kHz'

for name,fft in fft_list.items():
    if name==sig:
        continue
    nhalf = nhalves[name]
    plt.figure()
    plt.plot(np.linspace(0,nhalves[sig]*f,nhalves[sig]), fft[:nhalf], 'r',color=colors[name])
    rval = np.max(fft[4:7])/rmax
    gval = np.max(fft[14:17])/gmax
    bval = np.max(fft[24:27])/bmax
    print name,'rgb=',rval,gval,bval
    plt.xlabel('freq. [kHz]')
    plt.ylabel('|P(w)|')
    plt.title('Power Spectrum: '+name)
    plt.show()
# Out:
# 20.0 kHz
# pickup: (7,10,0)
#  rgb= 0.0215238613606 0.0358794868981 0.1049272274
# pickup: (7,5,4) rgb= 0.0176022827032 0.0708870562484 0.147503911329
# pickup: (6,9,4) rgb= 0.035072950072 0.0657319250439 0.202375140648
# pickup: (6,12,8) rgb= 0.0157653323812 0.0598989810761 0.114497531027
# pickup: (6,11,14) rgb= 0.0321308441575 0.0919027207461 0.117359472206
